# %% [markdown]
# ## Questão 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data4 = pd.read_csv('csv_result-Genes_Atividade_IA.csv')

# %% [markdown]
# ### Verificação de ausência de dados com *insnull().sum()*, podemos ver que não existe ausência de dados no dataset

# %%
data4.isnull().sum()
# Out:
# id                 0
# adipose_tissue     0
# adrenal_gland      0
# animal_ovary       0
# appendix           0
# bladder            0
# bone_marrow        0
# cerebral_cortex    0
# colon              0
# duodenum           0
# endometrium        0
# esophagus          0
# fallopian_tube     0
# gallbladder        0
# heart              0
# kidney             0
# liver              0
# lung               0
# lymph_node         0
# pancreas           0
# placenta           0
# prostate           0
# rectum             0
# salivary_gland     0
# skeletal_muscle    0
# skin               0
# small_intestine    0
# smooth_muscle      0
# spleen             0
# stomach            0
# testis             0
# thyroid            0
# tonsil             0
# class              0
# dtype: int64

# %%
data4.head()
# Out:
#    id  adipose_tissue  adrenal_gland  animal_ovary    appendix     bladder  \
# 0   1       31.730678      27.947800    109.900798   10.676703   88.592974
# 1   2       22.211475       0.621062      7.850057    2.491231    0.708744
# 2   3       79.326695     124.212446    102.050741  103.208129  116.942725
# 3   4        6.346136       9.315933     15.700114   14.235604   14.174876
# 4   5        2.221147       2.794780      3.925029    7.117802    3.543719
#
#    bone_marrow  cerebral_cortex      colon   duodenum       ...         \
# 0     0.628672        15.263091  70.636083  30.415583       ...
# 1     0.000003         0.000004   1.535567   0.276505       ...
# 2    88.014135        61.052363  85.991753  66.361272       ...
# 3     3.143362         7.631545  12.284536   8.295159       ...
# 4     6.286724         2.289464   3.071134   2.765053       ...
#
#    skeletal_muscle       skin  small_intestine  smooth_muscle     spleen  \
# 0         1.281708   9.914097        23.935905      21.242137  18.392589
# 1         0.000002   0.330470         0.299199       1.699371   0.735704
# 2        27.770329  72.703379        80.783681     101.962255  99.319983
# 3         2.136179  13.218796         8.975965      12.745282  14.714072
# 4         0.213618   3.304699         2.991988       4.248427   3.678518
#
#      stomach      testis     thyroid      tonsil            class
# 0  23.496108   66.480961   59.541743   15.873599  ENSG00000000003
# 1   0.000003    0.349900    0.458013    0.317472  ENSG00000000005
# 2  67.551311  129.462925  160.304693  117.464636  ENSG00000000419
# 3  11.748054   13.995992   18.320536   12.698880  ENSG00000000457
# 4   2.349611   17.494990    3.664107    9.524160  ENSG00000000460
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Removendo coluna *id* gerada após a conversão para csv. Como se trata de *Clusterização* vamos  remover a ultima coluna *Class*

# %%
del data4['id']
del data4['class']

# %%
data4.head()
# Out:
#    adipose_tissue  adrenal_gland  animal_ovary    appendix     bladder  \
# 0       31.730678      27.947800    109.900798   10.676703   88.592974
# 1       22.211475       0.621062      7.850057    2.491231    0.708744
# 2       79.326695     124.212446    102.050741  103.208129  116.942725
# 3        6.346136       9.315933     15.700114   14.235604   14.174876
# 4        2.221147       2.794780      3.925029    7.117802    3.543719
#
#    bone_marrow  cerebral_cortex      colon   duodenum  endometrium  \
# 0     0.628672        15.263091  70.636083  30.415583    59.427387
# 1     0.000003         0.000004   1.535567   0.276505     0.848963
# 2    88.014135        61.052363  85.991753  66.361272   131.589213
# 3     3.143362         7.631545  12.284536   8.295159    16.979253
# 4     6.286724         2.289464   3.071134   2.765053     8.489627
#
#       ...      salivary_gland  skeletal_muscle       skin  small_intestine  \
# 0     ...           61.691701         1.281708   9.914097        23.935905
# 1     ...            0.536450         0.000002   0.330470         0.299199
# 2     ...           40.233718        27.770329  72.703379        80.783681
# 3     ...            5.364496         2.136179  13.218796         8.975965
# 4     ...            1.072899         0.213618   3.304699         2.991988
#
#    smooth_muscle     spleen    stomach      testis     thyroid      tonsil
# 0      21.242137  18.392589  23.496108   66.480961   59.541743   15.873599
# 1       1.699371   0.735704   0.000003    0.349900    0.458013    0.317472
# 2     101.962255  99.319983  67.551311  129.462925  160.304693  117.464636
# 3      12.745282  14.714072  11.748054   13.995992   18.320536   12.698880
# 4       4.248427   3.678518   2.349611   17.494990    3.664107    9.524160
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Removendo dados duplicados

# %%
data4 = data4.drop_duplicates(None, 'first')

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999 entries, 0 to 1999
# Data columns (total 32 columns):
# adipose_tissue     1999 non-null float64
# adrenal_gland      1999 non-null float64
# animal_ovary       1999 non-null float64
# appendix           1999 non-null float64
# bladder            1999 non-null float64
# bone_marrow        1999 non-null float64
# cerebral_cortex    1999 non-null float64
# colon              1999 non-null float64
# duodenum           1999 non-null float64
# endometrium        1999 non-null float64
# esophagus          1999 non-null float64
# fallopian_tube     1999 non-null float64
# gallbladder        1999 non-null float64
# heart              1999 non-null float64
# kidney             1999 non-null float64
# liver              1999 non-null float64
# lung               1999 non-null float64
# lymph_node         1999 non-null float64
# pancreas           1999 non-null float64
# placenta           1999 non-null float64
# prostate           1999 non-null float64
# rectum             1999 non-null float64
# salivary_gland     1999 non-null float64
# skeletal_muscle    1999 non-null float64
# skin               1999 non-null float64
# small_intestine    1999 non-null float64
# smooth_muscle      1999 non-null float64
# spleen             1999 non-null float64
# stomach            1999 non-null float64
# testis             1999 non-null float64
# thyroid            1999 non-null float64
# tonsil             1999 non-null float64
# dtypes: float64(32)
# memory usage: 515.4 KB

# %% [markdown]
# ### Matriz de correlação

# %%
df = pd.DataFrame(data4)
corr = df.corr()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col0 {
#             background-color:  #023858;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col1 {
#             background-color:  #62a2cb;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col2 {
#             background-color:  #0567a2;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col3 {
#             background-color:  #0c74b2;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col4 {
#             background-color:  #03517e;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col5 {
#             background-color:  #96b6d7;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col6 {
#             background-color:  #3f93c2;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col7 {
#             background-color:  #2182b9;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col8 {
#             background-color:  #4496c3;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col9 {
#             background-color:  #2383ba;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col10 {
#             background-color:  #3790c0;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col11 {
#             background-color:  #93b5d6;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col12 {
#             background-color:  #034d79;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col13 {
#             background-color:  #b9c6e0;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col14 {
#             background-color:  #045382;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col15 {
#             background-color:  #b0c2de;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col16 {
#             background-color:  #045382;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col17 {
#             background-color:  #187cb6;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col18 {
#             background-color:  #fdf5fa;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col19 {
#             background-color:  #03476f;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col20 {
#             background-color:  #b3c3de;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col21 {
#             background-color:  #1077b4;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col22 {
#             background-color:  #ece7f2;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col23 {
#             background-color:  #f0eaf4;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col24 {
#             background-color:  #67a4cc;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col25 {
#             background-color:  #1278b4;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col26 {
#             background-color:  #1b7eb7;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col27 {
#             background-color:  #045b8e;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col28 {
#             background-color:  #89b1d4;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col29 {
#             background-color:  #75a9cf;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col30 {
#             background-color:  #dfddec;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row0_col31 {
#             background-color:  #529bc7;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col0 {
#             background-color:  #63a2cb;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col1 {
#             background-color:  #023858;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col2 {
#             background-color:  #7eadd1;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col3 {
#             background-color:  #8cb3d5;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col4 {
#             background-color:  #67a4cc;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col5 {
#             background-color:  #d2d3e7;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col6 {
#             background-color:  #80aed2;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col7 {
#             background-color:  #99b8d8;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col8 {
#             background-color:  #9fbad9;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col9 {
#             background-color:  #89b1d4;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col10 {
#             background-color:  #94b6d7;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col11 {
#             background-color:  #c4cbe3;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col12 {
#             background-color:  #6da6cd;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col13 {
#             background-color:  #d8d7e9;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col14 {
#             background-color:  #549cc7;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col15 {
#             background-color:  #d6d6e9;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col16 {
#             background-color:  #6fa7ce;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col17 {
#             background-color:  #91b5d6;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col18 {
#             background-color:  #fef6fa;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col19 {
#             background-color:  #60a1ca;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col20 {
#             background-color:  #d3d4e7;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col21 {
#             background-color:  #8fb4d6;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col22 {
#             background-color:  #f1ebf5;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col23 {
#             background-color:  #f7f0f7;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col24 {
#             background-color:  #a5bddb;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col25 {
#             background-color:  #89b1d4;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col26 {
#             background-color:  #8eb3d5;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col27 {
#             background-color:  #7bacd1;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col28 {
#             background-color:  #c6cce3;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col29 {
#             background-color:  #acc0dd;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col30 {
#             background-color:  #ebe6f2;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row1_col31 {
#             background-color:  #a4bcda;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col0 {
#             background-color:  #0567a2;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col1 {
#             background-color:  #7dacd1;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col2 {
#             background-color:  #023858;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col3 {
#             background-color:  #1b7eb7;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col4 {
#             background-color:  #056dac;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col5 {
#             background-color:  #abbfdc;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col6 {
#             background-color:  #3d93c2;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col7 {
#             background-color:  #2383ba;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col8 {
#             background-color:  #79abd0;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col9 {
#             background-color:  #0f76b3;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col10 {
#             background-color:  #308cbe;
#         }    #T_2cefd6d2_d97b_11e8_abfc_50b7c341d975row2_col11 {
#             background-color:  #83afd3;
#         }    #T_2cefd6d2_d97b_11e

# %% [markdown]
# #### por serem muitas colunas com a correlação muito alta, então optamos por juntar todas

# %% [markdown]
# ### Mesclando colunas com alta correlação

# %%
    data4['endo_smot_mus']=data4.endometrium.combine(data4.smooth_muscle, lambda x1, x2: (x1+x2)/2)
    data4['lymph_appendix']=data4.lymph_node.combine(data4.appendix, lambda x1, x2: (x1+x2)/2)
    data4['lung_spleen']=data4.lung.combine(data4.spleen, lambda x1, x2: (x1+x2)/2)
    data4['rectum_colon']=data4.rectum.combine(data4.colon, lambda x1, x2: (x1+x2)/2)
    data4['bg']=data4.bladder.combine(data4.gallbladder, lambda x1, x2: (x1+x2)/2)

# %%
df = pd.DataFrame(data4)
corr = df.corr()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col0 {
#             background-color:  #023858;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col1 {
#             background-color:  #62a2cb;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col2 {
#             background-color:  #0567a2;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col3 {
#             background-color:  #0c74b2;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col4 {
#             background-color:  #03517e;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col5 {
#             background-color:  #96b6d7;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col6 {
#             background-color:  #3f93c2;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col7 {
#             background-color:  #2182b9;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col8 {
#             background-color:  #4496c3;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col9 {
#             background-color:  #2383ba;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col10 {
#             background-color:  #3790c0;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col11 {
#             background-color:  #93b5d6;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col12 {
#             background-color:  #034d79;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col13 {
#             background-color:  #b9c6e0;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col14 {
#             background-color:  #045382;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col15 {
#             background-color:  #b0c2de;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col16 {
#             background-color:  #045382;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col17 {
#             background-color:  #187cb6;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col18 {
#             background-color:  #fdf5fa;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col19 {
#             background-color:  #03476f;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col20 {
#             background-color:  #b3c3de;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col21 {
#             background-color:  #1077b4;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col22 {
#             background-color:  #ece7f2;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col23 {
#             background-color:  #f0eaf4;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col24 {
#             background-color:  #67a4cc;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col25 {
#             background-color:  #1278b4;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col26 {
#             background-color:  #1b7eb7;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col27 {
#             background-color:  #045b8e;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col28 {
#             background-color:  #89b1d4;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col29 {
#             background-color:  #75a9cf;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col30 {
#             background-color:  #dfddec;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col31 {
#             background-color:  #529bc7;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col32 {
#             background-color:  #1c7fb8;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col33 {
#             background-color:  #1077b4;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col34 {
#             background-color:  #045585;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col35 {
#             background-color:  #167bb6;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row0_col36 {
#             background-color:  #034c78;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col0 {
#             background-color:  #63a2cb;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col1 {
#             background-color:  #023858;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col2 {
#             background-color:  #7eadd1;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col3 {
#             background-color:  #8cb3d5;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col4 {
#             background-color:  #67a4cc;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col5 {
#             background-color:  #d2d3e7;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col6 {
#             background-color:  #80aed2;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col7 {
#             background-color:  #99b8d8;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col8 {
#             background-color:  #9fbad9;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col9 {
#             background-color:  #89b1d4;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col10 {
#             background-color:  #94b6d7;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col11 {
#             background-color:  #c4cbe3;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col12 {
#             background-color:  #6da6cd;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col13 {
#             background-color:  #d8d7e9;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col14 {
#             background-color:  #549cc7;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col15 {
#             background-color:  #d6d6e9;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col16 {
#             background-color:  #6fa7ce;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col17 {
#             background-color:  #91b5d6;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col18 {
#             background-color:  #fef6fa;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col19 {
#             background-color:  #60a1ca;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col20 {
#             background-color:  #d3d4e7;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col21 {
#             background-color:  #8fb4d6;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col22 {
#             background-color:  #f1ebf5;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col23 {
#             background-color:  #f7f0f7;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col24 {
#             background-color:  #a5bddb;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col25 {
#             background-color:  #89b1d4;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col26 {
#             background-color:  #8eb3d5;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col27 {
#             background-color:  #7bacd1;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col28 {
#             background-color:  #c6cce3;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col29 {
#             background-color:  #acc0dd;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col30 {
#             background-color:  #ebe6f2;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col31 {
#             background-color:  #a4bcda;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col32 {
#             background-color:  #8bb2d4;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col33 {
#             background-color:  #8eb3d5;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col34 {
#             background-color:  #75a9cf;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col35 {
#             background-color:  #93b5d6;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row1_col36 {
#             background-color:  #67a4cc;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row2_col0 {
#             background-color:  #0567a2;
#         }    #T_2e0e78b6_d97b_11e8_abfc_50b7c341d975row2_col1 {
#             background-color:  #7dacd1;
#         }    #T_2e0e78b6_

# %% [markdown]
# ### Mesclando colunas com alta correlação

# %%
    data4['lymph_appendix_tonsil']=data4['lymph_appendix'].combine(data4.tonsil, lambda x1, x2: (x1+x2)/2)
    data4['bg_placent']=data4['bg'].combine(data4.placenta, lambda x1, x2: (x1+x2)/2)
    data4['bg_placent_adtiss']=data4['bg_placent'].combine(data4.adipose_tissue, lambda x1, x2: (x1+x2)/2)
    data4['bg_placent_adtiss_lung_spleen']=data4['bg_placent_adtiss'].combine(data4['lung_spleen'], lambda x1, x2: (x1+x2)/2)

# %%
df = pd.DataFrame(data4)
corr = df.corr()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col0 {
#             background-color:  #023858;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col1 {
#             background-color:  #62a2cb;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col2 {
#             background-color:  #0567a2;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col3 {
#             background-color:  #0c74b2;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col4 {
#             background-color:  #03517e;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col5 {
#             background-color:  #96b6d7;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col6 {
#             background-color:  #3f93c2;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col7 {
#             background-color:  #2182b9;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col8 {
#             background-color:  #4496c3;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col9 {
#             background-color:  #2383ba;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col10 {
#             background-color:  #3790c0;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col11 {
#             background-color:  #93b5d6;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col12 {
#             background-color:  #034d79;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col13 {
#             background-color:  #b9c6e0;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col14 {
#             background-color:  #045382;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col15 {
#             background-color:  #b0c2de;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col16 {
#             background-color:  #045382;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col17 {
#             background-color:  #187cb6;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col18 {
#             background-color:  #fdf5fa;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col19 {
#             background-color:  #03476f;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col20 {
#             background-color:  #b3c3de;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col21 {
#             background-color:  #1077b4;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col22 {
#             background-color:  #ece7f2;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col23 {
#             background-color:  #f0eaf4;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col24 {
#             background-color:  #67a4cc;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col25 {
#             background-color:  #1278b4;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col26 {
#             background-color:  #1b7eb7;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col27 {
#             background-color:  #045b8e;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col28 {
#             background-color:  #89b1d4;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col29 {
#             background-color:  #75a9cf;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col30 {
#             background-color:  #dfddec;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col31 {
#             background-color:  #529bc7;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col32 {
#             background-color:  #1c7fb8;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col33 {
#             background-color:  #1077b4;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col34 {
#             background-color:  #045585;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col35 {
#             background-color:  #167bb6;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col36 {
#             background-color:  #034c78;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col37 {
#             background-color:  #2987bc;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col38 {
#             background-color:  #03466e;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col39 {
#             background-color:  #023c5f;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row0_col40 {
#             background-color:  #03466e;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col0 {
#             background-color:  #63a2cb;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col1 {
#             background-color:  #023858;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col2 {
#             background-color:  #7eadd1;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col3 {
#             background-color:  #8cb3d5;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col4 {
#             background-color:  #67a4cc;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col5 {
#             background-color:  #d2d3e7;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col6 {
#             background-color:  #80aed2;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col7 {
#             background-color:  #99b8d8;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col8 {
#             background-color:  #9fbad9;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col9 {
#             background-color:  #89b1d4;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col10 {
#             background-color:  #94b6d7;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col11 {
#             background-color:  #c4cbe3;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col12 {
#             background-color:  #6da6cd;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col13 {
#             background-color:  #d8d7e9;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col14 {
#             background-color:  #549cc7;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col15 {
#             background-color:  #d6d6e9;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col16 {
#             background-color:  #6fa7ce;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col17 {
#             background-color:  #91b5d6;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col18 {
#             background-color:  #fef6fa;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col19 {
#             background-color:  #60a1ca;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col20 {
#             background-color:  #d3d4e7;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col21 {
#             background-color:  #8fb4d6;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col22 {
#             background-color:  #f1ebf5;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col23 {
#             background-color:  #f7f0f7;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col24 {
#             background-color:  #a5bddb;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col25 {
#             background-color:  #89b1d4;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col26 {
#             background-color:  #8eb3d5;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col27 {
#             background-color:  #7bacd1;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col28 {
#             background-color:  #c6cce3;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col29 {
#             background-color:  #acc0dd;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col30 {
#             background-color:  #ebe6f2;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col31 {
#             background-color:  #a4bcda;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col32 {
#             background-color:  #8bb2d4;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col33 {
#             background-color:  #8eb3d5;
#         }    #T_2f371afe_d97b_11e8_abfc_50b7c341d975row1_col34 {
#             background-color:  #75a9cf;
#         }    #T_2f371af

# %% [markdown]
# ### Removendo todas as colunas que foram mescladas

# %%
    del data4['endometrium']
    del data4['smooth_muscle']
    del data4['lymph_node']
    del data4['appendix']
    del data4['lung']
    del data4['spleen']
    del data4['tonsil']
    del data4['lymph_appendix']
    del data4['rectum']
    del data4['colon']
    del data4['bladder']
    del data4['gallbladder']
    del data4['bg']
    del data4['placenta']
    del data4['bg_placent']
    del data4['adipose_tissue']
    del data4['bg_placent_adtiss']
    del data4['lung_spleen']

# %%
df = pd.DataFrame(data4)
corr = df.corr()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col0 {
#             background-color:  #023858;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col1 {
#             background-color:  #7eadd1;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col2 {
#             background-color:  #d2d3e7;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col3 {
#             background-color:  #80aed2;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col4 {
#             background-color:  #9fbad9;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col5 {
#             background-color:  #94b6d7;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col6 {
#             background-color:  #c4cbe3;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col7 {
#             background-color:  #d8d7e9;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col8 {
#             background-color:  #549cc7;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col9 {
#             background-color:  #d6d6e9;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col10 {
#             background-color:  #fef6fa;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col11 {
#             background-color:  #d3d4e7;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col12 {
#             background-color:  #f1ebf5;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col13 {
#             background-color:  #f7f0f7;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col14 {
#             background-color:  #a5bddb;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col15 {
#             background-color:  #89b1d4;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col16 {
#             background-color:  #c6cce3;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col17 {
#             background-color:  #acc0dd;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col18 {
#             background-color:  #ebe6f2;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col19 {
#             background-color:  #8bb2d4;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col20 {
#             background-color:  #93b5d6;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col21 {
#             background-color:  #96b6d7;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row0_col22 {
#             background-color:  #67a4cc;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col0 {
#             background-color:  #7dacd1;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col1 {
#             background-color:  #023858;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col2 {
#             background-color:  #abbfdc;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col3 {
#             background-color:  #3d93c2;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col4 {
#             background-color:  #79abd0;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col5 {
#             background-color:  #308cbe;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col6 {
#             background-color:  #83afd3;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col7 {
#             background-color:  #cacee5;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col8 {
#             background-color:  #2f8bbe;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col9 {
#             background-color:  #d2d3e7;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col10 {
#             background-color:  #fdf5fa;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col11 {
#             background-color:  #b8c6e0;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col12 {
#             background-color:  #eae6f1;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col13 {
#             background-color:  #f5eef6;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col14 {
#             background-color:  #3f93c2;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col15 {
#             background-color:  #3f93c2;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col16 {
#             background-color:  #97b7d7;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col17 {
#             background-color:  #71a8ce;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col18 {
#             background-color:  #e2dfee;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col19 {
#             background-color:  #187cb6;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col20 {
#             background-color:  #2182b9;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col21 {
#             background-color:  #2786bb;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row1_col22 {
#             background-color:  #056ead;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col0 {
#             background-color:  #d3d4e7;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col1 {
#             background-color:  #adc1dd;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col2 {
#             background-color:  #023858;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col3 {
#             background-color:  #c5cce3;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col4 {
#             background-color:  #0c74b2;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col5 {
#             background-color:  #abbfdc;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col6 {
#             background-color:  #d8d7e9;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col7 {
#             background-color:  #ebe6f2;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col8 {
#             background-color:  #a1bbda;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col9 {
#             background-color:  #e6e2ef;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col10 {
#             background-color:  #fef6fb;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col11 {
#             background-color:  #e0deed;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col12 {
#             background-color:  #0569a5;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col13 {
#             background-color:  #fbf4f9;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col14 {
#             background-color:  #c2cbe2;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col15 {
#             background-color:  #75a9cf;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col16 {
#             background-color:  #05659f;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col17 {
#             background-color:  #d2d2e7;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col18 {
#             background-color:  #f2ecf5;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col19 {
#             background-color:  #a8bedc;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col20 {
#             background-color:  #a2bcda;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col21 {
#             background-color:  #7eadd1;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row2_col22 {
#             background-color:  #76aad0;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row3_col0 {
#             background-color:  #81aed2;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row3_col1 {
#             background-color:  #3f93c2;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row3_col2 {
#             background-color:  #c5cce3;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row3_col3 {
#             background-color:  #023858;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row3_col4 {
#             background-color:  #94b6d7;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row3_col5 {
#             background-color:  #4094c3;
#         }    #T_2f371aff_d97b_11e8_abfc_50b7c341d975row3_col6 {
#             background-color:  #a8bedc;
#         }    #T_2f371aff_d97b_11e8_abfc_

# %% [markdown]
# ### Mesclando colunas com alta correlação

# %%
    data4['bg_placent_adtiss_lung_spleen_kidney']=data4['bg_placent_adtiss_lung_spleen'].combine(data4['kidney'], lambda x1, x2: (x1+x2)/2)

# %% [markdown]
# ### Removendo todas as colunas que foram mescladas

# %%
del data4['bg_placent_adtiss_lung_spleen']
del data4['kidney']

# %%
df = pd.DataFrame(data4)
corr = df.corr()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col0 {
#             background-color:  #023858;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col1 {
#             background-color:  #7eadd1;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col2 {
#             background-color:  #d2d3e7;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col3 {
#             background-color:  #80aed2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col4 {
#             background-color:  #9fbad9;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col5 {
#             background-color:  #94b6d7;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col6 {
#             background-color:  #c4cbe3;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col7 {
#             background-color:  #d8d7e9;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col8 {
#             background-color:  #d6d6e9;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col9 {
#             background-color:  #fef6fa;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col10 {
#             background-color:  #d3d4e7;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col11 {
#             background-color:  #f1ebf5;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col12 {
#             background-color:  #f7f0f7;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col13 {
#             background-color:  #a5bddb;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col14 {
#             background-color:  #89b1d4;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col15 {
#             background-color:  #c6cce3;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col16 {
#             background-color:  #acc0dd;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col17 {
#             background-color:  #ebe6f2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col18 {
#             background-color:  #8bb2d4;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col19 {
#             background-color:  #93b5d6;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col20 {
#             background-color:  #96b6d7;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row0_col21 {
#             background-color:  #5a9ec9;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col0 {
#             background-color:  #7dacd1;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col1 {
#             background-color:  #023858;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col2 {
#             background-color:  #abbfdc;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col3 {
#             background-color:  #3d93c2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col4 {
#             background-color:  #79abd0;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col5 {
#             background-color:  #308cbe;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col6 {
#             background-color:  #83afd3;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col7 {
#             background-color:  #cacee5;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col8 {
#             background-color:  #d2d3e7;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col9 {
#             background-color:  #fdf5fa;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col10 {
#             background-color:  #b8c6e0;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col11 {
#             background-color:  #eae6f1;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col12 {
#             background-color:  #f5eef6;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col13 {
#             background-color:  #3f93c2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col14 {
#             background-color:  #3f93c2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col15 {
#             background-color:  #97b7d7;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col16 {
#             background-color:  #71a8ce;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col17 {
#             background-color:  #e2dfee;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col18 {
#             background-color:  #187cb6;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col19 {
#             background-color:  #2182b9;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col20 {
#             background-color:  #2786bb;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row1_col21 {
#             background-color:  #0a73b2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col0 {
#             background-color:  #d3d4e7;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col1 {
#             background-color:  #adc1dd;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col2 {
#             background-color:  #023858;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col3 {
#             background-color:  #c5cce3;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col4 {
#             background-color:  #0c74b2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col5 {
#             background-color:  #abbfdc;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col6 {
#             background-color:  #d8d7e9;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col7 {
#             background-color:  #ebe6f2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col8 {
#             background-color:  #e6e2ef;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col9 {
#             background-color:  #fef6fb;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col10 {
#             background-color:  #e0deed;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col11 {
#             background-color:  #0569a5;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col12 {
#             background-color:  #fbf4f9;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col13 {
#             background-color:  #c2cbe2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col14 {
#             background-color:  #75a9cf;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col15 {
#             background-color:  #05659f;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col16 {
#             background-color:  #d2d2e7;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col17 {
#             background-color:  #f2ecf5;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col18 {
#             background-color:  #a8bedc;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col19 {
#             background-color:  #a2bcda;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col20 {
#             background-color:  #7eadd1;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row2_col21 {
#             background-color:  #80aed2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row3_col0 {
#             background-color:  #81aed2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row3_col1 {
#             background-color:  #3f93c2;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row3_col2 {
#             background-color:  #c5cce3;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row3_col3 {
#             background-color:  #023858;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row3_col4 {
#             background-color:  #94b6d7;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row3_col5 {
#             background-color:  #4094c3;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row3_col6 {
#             background-color:  #a8bedc;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row3_col7 {
#             background-color:  #d2d2e7;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row3_col8 {
#             background-color:  #d9d8ea;
#         }    #T_2f371b00_d97b_11e8_abfc_50b7c341d975row3_col9 {
#             background-color:  #fef6fb;
#         }    #T_2f371b00_d97b_11e8_abfc_50b

# %% [markdown]
# #### Normalizando e preparando dada dos para treinamento

# %%
features = data4.iloc[:,0:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(features)
MinMaxScaler(copy=True, feature_range=(0, 1))
features=scaler.transform(features)

# %% [markdown]
# ## Kmeans

# %% [markdown]
# ### KMeans com *n_clusters = 2*

# %%
from sklearn.cluster import KMeans

clf_2 = KMeans(n_clusters = 2, init = 'k-means++',max_iter=200)
clf_2.fit(features)

clusters_kmeans_2 = clf_2.predict(features)

table_kmeans_2 = features
table_kmeans_2=pd.DataFrame(table_kmeans_2)

table_kmeans_2['clusters_kmeans'] = clusters_kmeans_2

qtd_clusters_2=table_kmeans_2['clusters_kmeans'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_clusters_2[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_clusters_2[1])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1996
# Cluster de indice [1] -> Num de instâncias:  3

# %%
hist_clusters_kmeans = pd.Categorical(qtd_clusters_2).codes
sns.distplot(hist_clusters_kmeans)
# Out:
# /home/curty/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### KMeans com *n_clusters = 5*

# %%
clf_5 = KMeans(n_clusters = 5, init = 'k-means++',max_iter=200)
clf_5.fit(features)

clusters_kmeans_5 = clf_5.predict(features)

table_kmeans_5 = features

table_kmeans_5=pd.DataFrame(table_kmeans_5)

table_kmeans_5['clusters_kmeans'] = clusters_kmeans_5

qtd_clusters_5=table_kmeans_5['clusters_kmeans'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_clusters_5[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_clusters_5[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_clusters_5[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_clusters_5[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_clusters_5[4])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1965
# Cluster de indice [1] -> Num de instâncias:  1
# Cluster de indice [2] -> Num de instâncias:  3
# Cluster de indice [3] -> Num de instâncias:  1
# Cluster de indice [4] -> Num de instâncias:  29

# %%
hist_clusters_kmeans = pd.Categorical(qtd_clusters_5).codes
sns.distplot(hist_clusters_kmeans)
# Out:
# /home/curty/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### KMeans com *n_clusters = 10*

# %%
clf_10 = KMeans(n_clusters = 10, init = 'k-means++',max_iter=200)
clf_10.fit(features)
clusters_kmeans_10 = clf_10.predict(features)
table_kmeans_10 = features
table_kmeans_10=pd.DataFrame(table_kmeans_10)
table_kmeans_10['clusters_kmeans'] = clusters_kmeans_10
qtd_clusters_10=table_kmeans_10['clusters_kmeans'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_clusters_10[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_clusters_10[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_clusters_10[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_clusters_10[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_clusters_10[4])
print("Cluster de indice [5] -> Num de instâncias: ",qtd_clusters_10[5])
print("Cluster de indice [6] -> Num de instâncias: ",qtd_clusters_10[6])
print("Cluster de indice [7] -> Num de instâncias: ",qtd_clusters_10[7])
print("Cluster de indice [8] -> Num de instâncias: ",qtd_clusters_10[8])
print("Cluster de indice [9] -> Num de instâncias: ",qtd_clusters_10[9])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1829
# Cluster de indice [1] -> Num de instâncias:  1
# Cluster de indice [2] -> Num de instâncias:  146
# Cluster de indice [3] -> Num de instâncias:  1
# Cluster de indice [4] -> Num de instâncias:  1
# Cluster de indice [5] -> Num de instâncias:  1
# Cluster de indice [6] -> Num de instâncias:  2
# Cluster de indice [7] -> Num de instâncias:  16
# Cluster de indice [8] -> Num de instâncias:  1
# Cluster de indice [9] -> Num de instâncias:  1

# %%
hist_clusters_kmeans = pd.Categorical(qtd_clusters_10).codes
sns.distplot(hist_clusters_kmeans)
# Out:
# /home/curty/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### KMeans com *n_clusters = 100*

# %%
clf_100 = KMeans(n_clusters = 100, init = 'k-means++',max_iter=200)
clf_100.fit(features)
clusters_kmeans_100 = clf_100.predict(features)

table_kmeans_100 = features

table_kmeans_100=pd.DataFrame(table_kmeans_100)

table_kmeans_100['clusters_kmeans'] = clusters_kmeans_100

qtd_clusters_100=table_kmeans_100['clusters_kmeans'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_clusters_100[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_clusters_100[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_clusters_100[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_clusters_100[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_clusters_100[4])
print("Cluster de indice [5] -> Num de instâncias: ",qtd_clusters_100[5])
print("Cluster de indice [6] -> Num de instâncias: ",qtd_clusters_100[6])
print("Cluster de indice [7] -> Num de instâncias: ",qtd_clusters_100[7])
print("Cluster de indice [8] -> Num de instâncias: ",qtd_clusters_100[8])
print("Cluster de indice [9] -> Num de instâncias: ",qtd_clusters_100[9])
# Out:
# Cluster de indice [0] -> Num de instâncias:  6
# Cluster de indice [1] -> Num de instâncias:  1
# Cluster de indice [2] -> Num de instâncias:  1
# Cluster de indice [3] -> Num de instâncias:  1
# Cluster de indice [4] -> Num de instâncias:  1
# Cluster de indice [5] -> Num de instâncias:  25
# Cluster de indice [6] -> Num de instâncias:  1
# Cluster de indice [7] -> Num de instâncias:  1
# Cluster de indice [8] -> Num de instâncias:  1
# Cluster de indice [9] -> Num de instâncias:  1

# %%
hist_clusters_kmeans = pd.Categorical(qtd_clusters_100).codes
sns.distplot(hist_clusters_kmeans)
# Out:
# /home/curty/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### *n_clusters=100* fixo e alterando *max_inter = 1*

# %%
clf_100 = KMeans(n_clusters = 100, init = 'k-means++',max_iter=1)
clf_100.fit(features)
clusters_kmeans_100 = clf_100.predict(features)

table_kmeans_100 = features

table_kmeans_100=pd.DataFrame(table_kmeans_100)

table_kmeans_100['clusters_kmeans'] = clusters_kmeans_100

qtd_clusters_100=table_kmeans_100['clusters_kmeans'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_clusters_100[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_clusters_100[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_clusters_100[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_clusters_100[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_clusters_100[4])
print("Cluster de indice [5] -> Num de instâncias: ",qtd_clusters_100[5])
print("Cluster de indice [6] -> Num de instâncias: ",qtd_clusters_100[6])
print("Cluster de indice [7] -> Num de instâncias: ",qtd_clusters_100[7])
print("Cluster de indice [8] -> Num de instâncias: ",qtd_clusters_100[8])
print("Cluster de indice [9] -> Num de instâncias: ",qtd_clusters_100[9])
# Out:
# Cluster de indice [0] -> Num de instâncias:  41
# Cluster de indice [1] -> Num de instâncias:  1
# Cluster de indice [2] -> Num de instâncias:  2
# Cluster de indice [3] -> Num de instâncias:  1
# Cluster de indice [4] -> Num de instâncias:  1
# Cluster de indice [5] -> Num de instâncias:  1
# Cluster de indice [6] -> Num de instâncias:  1
# Cluster de indice [7] -> Num de instâncias:  1
# Cluster de indice [8] -> Num de instâncias:  1
# Cluster de indice [9] -> Num de instâncias:  1

# %%
hist_clusters_kmeans = pd.Categorical(qtd_clusters_100).codes
sns.distplot(hist_clusters_kmeans)
# Out:
# /home/curty/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### *n_clusters=100* fixo e alterando *max_inter = 10*

# %%
clf_100 = KMeans(n_clusters = 100, init = 'k-means++',max_iter=10)
clf_100.fit(features)
clusters_kmeans_100 = clf_100.predict(features)

table_kmeans_100 = features

table_kmeans_100=pd.DataFrame(table_kmeans_100)

table_kmeans_100['clusters_kmeans'] = clusters_kmeans_100

qtd_clusters_100=table_kmeans_100['clusters_kmeans'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_clusters_100[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_clusters_100[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_clusters_100[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_clusters_100[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_clusters_100[4])
print("Cluster de indice [5] -> Num de instâncias: ",qtd_clusters_100[5])
print("Cluster de indice [6] -> Num de instâncias: ",qtd_clusters_100[6])
print("Cluster de indice [7] -> Num de instâncias: ",qtd_clusters_100[7])
print("Cluster de indice [8] -> Num de instâncias: ",qtd_clusters_100[8])
print("Cluster de indice [9] -> Num de instâncias: ",qtd_clusters_100[9])
# Out:
# Cluster de indice [0] -> Num de instâncias:  44
# Cluster de indice [1] -> Num de instâncias:  1
# Cluster de indice [2] -> Num de instâncias:  6
# Cluster de indice [3] -> Num de instâncias:  1
# Cluster de indice [4] -> Num de instâncias:  1
# Cluster de indice [5] -> Num de instâncias:  1
# Cluster de indice [6] -> Num de instâncias:  1
# Cluster de indice [7] -> Num de instâncias:  1
# Cluster de indice [8] -> Num de instâncias:  1
# Cluster de indice [9] -> Num de instâncias:  1

# %%
hist_clusters_kmeans = pd.Categorical(qtd_clusters_100).codes
sns.distplot(hist_clusters_kmeans)
# Out:
# /home/curty/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### *n_clusters=100* fixo e alterando *max_inter = 100*

# %%
clf_100 = KMeans(n_clusters = 100, init = 'k-means++',max_iter=100)
clf_100.fit(features)
clusters_kmeans_100 = clf_100.predict(features)

table_kmeans_100 = features

table_kmeans_100=pd.DataFrame(table_kmeans_100)

table_kmeans_100['clusters_kmeans'] = clusters_kmeans_100

qtd_clusters_100=table_kmeans_100['clusters_kmeans'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_clusters_100[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_clusters_100[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_clusters_100[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_clusters_100[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_clusters_100[4])
print("Cluster de indice [5] -> Num de instâncias: ",qtd_clusters_100[5])
print("Cluster de indice [6] -> Num de instâncias: ",qtd_clusters_100[6])
print("Cluster de indice [7] -> Num de instâncias: ",qtd_clusters_100[7])
print("Cluster de indice [8] -> Num de instâncias: ",qtd_clusters_100[8])
print("Cluster de indice [9] -> Num de instâncias: ",qtd_clusters_100[9])
# Out:
# Cluster de indice [0] -> Num de instâncias:  393
# Cluster de indice [1] -> Num de instâncias:  1
# Cluster de indice [2] -> Num de instâncias:  4
# Cluster de indice [3] -> Num de instâncias:  1
# Cluster de indice [4] -> Num de instâncias:  1
# Cluster de indice [5] -> Num de instâncias:  1
# Cluster de indice [6] -> Num de instâncias:  1
# Cluster de indice [7] -> Num de instâncias:  31
# Cluster de indice [8] -> Num de instâncias:  1
# Cluster de indice [9] -> Num de instâncias:  1

# %%
hist_clusters_kmeans = pd.Categorical(qtd_clusters_100).codes
sns.distplot(hist_clusters_kmeans)
# Out:
# /home/curty/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Hierárquico

# %% [markdown]
# ### Para *n_clusters = 2*

# %%
from scipy.cluster.hierarchy import dendrogram, linkage 
from scipy import cluster
import numpy as np , collections
import collections

Z = linkage(features,'ward','euclidean')
clusters_H = cluster.hierarchy.cut_tree(Z, n_clusters=2)
table_finale_H = features
table_finale_H = pd.DataFrame(table_finale_H)
table_finale_H['clusters_hierarquico'] = clusters_H
qtd_por_clusters_hier=table_finale_H['clusters_hierarquico'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_por_clusters_hier[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_por_clusters_hier[1])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1996
# Cluster de indice [1] -> Num de instâncias:  3

# %%
hist_clusters_kmeans = pd.Categorical(qtd_por_clusters_hier).codes
sns.distplot(hist_clusters_kmeans)

# %% [markdown]
# ### Para *n_clusters = 5*

# %%
Z = linkage(features,'ward','euclidean')
clusters_H = cluster.hierarchy.cut_tree(Z, n_clusters=5)
table_finale_H = features
table_finale_H = pd.DataFrame(table_finale_H)
table_finale_H['clusters_hierarquico'] = clusters_H
qtd_por_clusters_hier=table_finale_H['clusters_hierarquico'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_por_clusters_hier[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_por_clusters_hier[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_por_clusters_hier[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_por_clusters_hier[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_por_clusters_hier[4])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1903
# Cluster de indice [1] -> Num de instâncias:  81
# Cluster de indice [2] -> Num de instâncias:  11
# Cluster de indice [3] -> Num de instâncias:  3
# Cluster de indice [4] -> Num de instâncias:  1

# %%
hist_clusters_kmeans = pd.Categorical(qtd_por_clusters_hier).codes
sns.distplot(hist_clusters_kmeans)

# %% [markdown]
# ### Para *n_clusters = 10*

# %%
Z = linkage(features,'ward','euclidean')
clusters_H = cluster.hierarchy.cut_tree(Z, n_clusters=10)
table_finale_H = features
table_finale_H = pd.DataFrame(table_finale_H)
table_finale_H['clusters_hierarquico'] = clusters_H
qtd_por_clusters_hier=table_finale_H['clusters_hierarquico'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_por_clusters_hier[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_por_clusters_hier[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_por_clusters_hier[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_por_clusters_hier[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_por_clusters_hier[4])
print("Cluster de indice [5] -> Num de instâncias: ",qtd_por_clusters_hier[5])
print("Cluster de indice [6] -> Num de instâncias: ",qtd_por_clusters_hier[6])
print("Cluster de indice [7] -> Num de instâncias: ",qtd_por_clusters_hier[7])
print("Cluster de indice [8] -> Num de instâncias: ",qtd_por_clusters_hier[8])
print("Cluster de indice [9] -> Num de instâncias: ",qtd_por_clusters_hier[9])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1903
# Cluster de indice [1] -> Num de instâncias:  77
# Cluster de indice [2] -> Num de instâncias:  3
# Cluster de indice [3] -> Num de instâncias:  2
# Cluster de indice [4] -> Num de instâncias:  6
# Cluster de indice [5] -> Num de instâncias:  2
# Cluster de indice [6] -> Num de instâncias:  3
# Cluster de indice [7] -> Num de instâncias:  1
# Cluster de indice [8] -> Num de instâncias:  1
# Cluster de indice [9] -> Num de instâncias:  1

# %%
hist_clusters_kmeans = pd.Categorical(qtd_por_clusters_hier).codes
sns.distplot(hist_clusters_kmeans)

# %%
def plot_histogram_balancing(dataframe,class_name):
    print(dataframe[class_name].value_counts().to_dict())
    plt.show(dataframe.hist(column=class_name, color='red'))
    plt.clf()
    plt.cla()
    plt.close()

# %% [markdown]
# ### Para *n_clusters = 100*

# %%
Z = linkage(features,'ward','euclidean')
clusters_H = cluster.hierarchy.cut_tree(Z, n_clusters=100)
table_finale_H = features
table_finale_H = pd.DataFrame(table_finale_H)
table_finale_H['clusters_hierarquico'] = clusters_H
qtd_por_clusters_hier=table_finale_H['clusters_hierarquico'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_por_clusters_hier[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_por_clusters_hier[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_por_clusters_hier[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_por_clusters_hier[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_por_clusters_hier[4])
print("Cluster de indice [5] -> Num de instâncias: ",qtd_por_clusters_hier[5])
print("Cluster de indice [6] -> Num de instâncias: ",qtd_por_clusters_hier[6])
print("Cluster de indice [7] -> Num de instâncias: ",qtd_por_clusters_hier[7])
print("Cluster de indice [8] -> Num de instâncias: ",qtd_por_clusters_hier[8])
print("Cluster de indice [9] -> Num de instâncias: ",qtd_por_clusters_hier[9])
# Out:
# Cluster de indice [0] -> Num de instâncias:  213
# Cluster de indice [1] -> Num de instâncias:  352
# Cluster de indice [2] -> Num de instâncias:  20
# Cluster de indice [3] -> Num de instâncias:  366
# Cluster de indice [4] -> Num de instâncias:  10
# Cluster de indice [5] -> Num de instâncias:  29
# Cluster de indice [6] -> Num de instâncias:  115
# Cluster de indice [7] -> Num de instâncias:  36
# Cluster de indice [8] -> Num de instâncias:  13
# Cluster de indice [9] -> Num de instâncias:  360

# %%
hist_clusters_kmeans = pd.Categorical(qtd_por_clusters_hier).codes
sns.distplot(hist_clusters_kmeans)

# %% [markdown]
# ### Mantendo *n_clusters = 100* e alterando o method em *linkage = average*

# %%
Z = linkage(features,'average','euclidean')
clusters_H = cluster.hierarchy.cut_tree(Z, n_clusters=100)
table_finale_H = features
table_finale_H = pd.DataFrame(table_finale_H)
table_finale_H['clusters_hierarquico'] = clusters_H
qtd_por_clusters_hier=table_finale_H['clusters_hierarquico'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_por_clusters_hier[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_por_clusters_hier[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_por_clusters_hier[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_por_clusters_hier[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_por_clusters_hier[4])
print("Cluster de indice [5] -> Num de instâncias: ",qtd_por_clusters_hier[5])
print("Cluster de indice [6] -> Num de instâncias: ",qtd_por_clusters_hier[6])
print("Cluster de indice [7] -> Num de instâncias: ",qtd_por_clusters_hier[7])
print("Cluster de indice [8] -> Num de instâncias: ",qtd_por_clusters_hier[8])
print("Cluster de indice [9] -> Num de instâncias: ",qtd_por_clusters_hier[9])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1750
# Cluster de indice [1] -> Num de instâncias:  5
# Cluster de indice [2] -> Num de instâncias:  65
# Cluster de indice [3] -> Num de instâncias:  4
# Cluster de indice [4] -> Num de instâncias:  1
# Cluster de indice [5] -> Num de instâncias:  1
# Cluster de indice [6] -> Num de instâncias:  19
# Cluster de indice [7] -> Num de instâncias:  1
# Cluster de indice [8] -> Num de instâncias:  1
# Cluster de indice [9] -> Num de instâncias:  1

# %%
hist_clusters_kmeans = pd.Categorical(qtd_por_clusters_hier).codes
sns.distplot(hist_clusters_kmeans)

# %% [markdown]
# ### Mantendo *n_clusters = 100* e alterando o method em *linkage = centroid*

# %%
Z = linkage(features,'centroid','euclidean')
clusters_H = cluster.hierarchy.cut_tree(Z, n_clusters=100)
table_finale_H = features
table_finale_H = pd.DataFrame(table_finale_H)
table_finale_H['clusters_hierarquico'] = clusters_H
qtd_por_clusters_hier=table_finale_H['clusters_hierarquico'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_por_clusters_hier[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_por_clusters_hier[1])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1749
# Cluster de indice [1] -> Num de instâncias:  208

# %%
hist_clusters_kmeans = pd.Categorical(qtd_por_clusters_hier).codes
sns.distplot(hist_clusters_kmeans)

# %% [markdown]
# ### Mantendo *n_clusters = 100* e alterando o method em *linkage = weighted*

# %%
Z = linkage(features,'weighted','euclidean')
clusters_H = cluster.hierarchy.cut_tree(Z, n_clusters=100)
table_finale_H = features
table_finale_H = pd.DataFrame(table_finale_H)
table_finale_H['clusters_hierarquico'] = clusters_H
qtd_por_clusters_hier=table_finale_H['clusters_hierarquico'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_por_clusters_hier[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_por_clusters_hier[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_por_clusters_hier[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_por_clusters_hier[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_por_clusters_hier[4])
print("Cluster de indice [5] -> Num de instâncias: ",qtd_por_clusters_hier[5])
print("Cluster de indice [6] -> Num de instâncias: ",qtd_por_clusters_hier[6])
print("Cluster de indice [7] -> Num de instâncias: ",qtd_por_clusters_hier[7])
print("Cluster de indice [8] -> Num de instâncias: ",qtd_por_clusters_hier[8])
print("Cluster de indice [9] -> Num de instâncias: ",qtd_por_clusters_hier[9])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1698
# Cluster de indice [1] -> Num de instâncias:  11
# Cluster de indice [2] -> Num de instâncias:  67
# Cluster de indice [3] -> Num de instâncias:  25
# Cluster de indice [4] -> Num de instâncias:  20
# Cluster de indice [5] -> Num de instâncias:  7
# Cluster de indice [6] -> Num de instâncias:  1
# Cluster de indice [7] -> Num de instâncias:  1
# Cluster de indice [8] -> Num de instâncias:  1
# Cluster de indice [9] -> Num de instâncias:  1

# %%
hist_clusters_kmeans = pd.Categorical(qtd_por_clusters_hier).codes
sns.distplot(hist_clusters_kmeans)

# %% [markdown]
# ### Mantendo *n_clusters = 100* e alterando o method em *linkage = complete*

# %%
Z = linkage(features,'complete','euclidean')
clusters_H = cluster.hierarchy.cut_tree(Z, n_clusters=100)
table_finale_H = features
table_finale_H = pd.DataFrame(table_finale_H)
table_finale_H['clusters_hierarquico'] = clusters_H
qtd_por_clusters_hier=table_finale_H['clusters_hierarquico'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_por_clusters_hier[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_por_clusters_hier[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_por_clusters_hier[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_por_clusters_hier[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_por_clusters_hier[4])
print("Cluster de indice [5] -> Num de instâncias: ",qtd_por_clusters_hier[5])
print("Cluster de indice [6] -> Num de instâncias: ",qtd_por_clusters_hier[6])
print("Cluster de indice [7] -> Num de instâncias: ",qtd_por_clusters_hier[7])
print("Cluster de indice [8] -> Num de instâncias: ",qtd_por_clusters_hier[8])
print("Cluster de indice [9] -> Num de instâncias: ",qtd_por_clusters_hier[9])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1571
# Cluster de indice [1] -> Num de instâncias:  78
# Cluster de indice [2] -> Num de instâncias:  11
# Cluster de indice [3] -> Num de instâncias:  15
# Cluster de indice [4] -> Num de instâncias:  11
# Cluster de indice [5] -> Num de instâncias:  11
# Cluster de indice [6] -> Num de instâncias:  5
# Cluster de indice [7] -> Num de instâncias:  7
# Cluster de indice [8] -> Num de instâncias:  32
# Cluster de indice [9] -> Num de instâncias:  4

# %%
hist_clusters_kmeans = pd.Categorical(qtd_por_clusters_hier).codes
sns.distplot(hist_clusters_kmeans)

# %% [markdown]
# ### Mantendo *n_clusters = 100* e alterando o method em *linkage = median*

# %%
Z = linkage(features,'median','euclidean')
clusters_H = cluster.hierarchy.cut_tree(Z, n_clusters=100)
table_finale_H = features
table_finale_H = pd.DataFrame(table_finale_H)
table_finale_H['clusters_hierarquico'] = clusters_H
qtd_por_clusters_hier=table_finale_H['clusters_hierarquico'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_por_clusters_hier[0])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1963

# %%
hist_clusters_kmeans = pd.Categorical(qtd_por_clusters_hier).codes
sns.distplot(hist_clusters_kmeans)

# %% [markdown]
# ### Mantendo *n_clusters = 100* e alterando o method em *linkage = single*

# %%
Z = linkage(features,'single','euclidean')
clusters_H = cluster.hierarchy.cut_tree(Z, n_clusters=100)
table_finale_H = features
table_finale_H = pd.DataFrame(table_finale_H)
table_finale_H['clusters_hierarquico'] = clusters_H
qtd_por_clusters_hier=table_finale_H['clusters_hierarquico'].value_counts()

print("Cluster de indice [0] -> Num de instâncias: ",qtd_por_clusters_hier[0])
print("Cluster de indice [1] -> Num de instâncias: ",qtd_por_clusters_hier[1])
print("Cluster de indice [2] -> Num de instâncias: ",qtd_por_clusters_hier[2])
print("Cluster de indice [3] -> Num de instâncias: ",qtd_por_clusters_hier[3])
print("Cluster de indice [4] -> Num de instâncias: ",qtd_por_clusters_hier[4])
print("Cluster de indice [5] -> Num de instâncias: ",qtd_por_clusters_hier[5])
print("Cluster de indice [6] -> Num de instâncias: ",qtd_por_clusters_hier[6])
print("Cluster de indice [7] -> Num de instâncias: ",qtd_por_clusters_hier[7])
print("Cluster de indice [8] -> Num de instâncias: ",qtd_por_clusters_hier[8])
print("Cluster de indice [9] -> Num de instâncias: ",qtd_por_clusters_hier[9])
# Out:
# Cluster de indice [0] -> Num de instâncias:  1896
# Cluster de indice [1] -> Num de instâncias:  1
# Cluster de indice [2] -> Num de instâncias:  1
# Cluster de indice [3] -> Num de instâncias:  1
# Cluster de indice [4] -> Num de instâncias:  1
# Cluster de indice [5] -> Num de instâncias:  1
# Cluster de indice [6] -> Num de instâncias:  1
# Cluster de indice [7] -> Num de instâncias:  1
# Cluster de indice [8] -> Num de instâncias:  1
# Cluster de indice [9] -> Num de instâncias:  1

# %%
hist_clusters_kmeans = pd.Categorical(qtd_por_clusters_hier).codes
sns.distplot(hist_clusters_kmeans)

# %% [markdown]
# ### Analisando os gráficos, o algoritmo de agrupamento Hierárquico se saiu melhor, por ter agrupado um maior número de instâncias
